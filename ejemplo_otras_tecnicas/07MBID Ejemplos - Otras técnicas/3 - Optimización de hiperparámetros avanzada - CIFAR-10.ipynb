# %% [markdown]
# # Optimización de hiper-parámetros - Avanzado
#
# En este notebook jugaremos con dos tipos de optimización de hiperparámetros más complicados:
# * Hyperopt
# * Algoritmos genéticos

# %% [markdown]
# ## Hyper-opt
#
# (Hyperopt: Distributed Asynchronous Hyper-parameter Optimization, https://github.com/hyperopt/hyperopt).
#
# Hyperopt es una librería escrita en Python que permite optimizar funciones de una forma rápida fijándose más en los valores que más probablemente van a dar una buena solución.
#
# Actualmente tiene dos algoritmos implementados para hacer esto:
#
# * Random Search
# * Tree of Parzen Estimators (TPE)
#
# Además, se pueden ejecutar en serie o en paralelo, haciendo uso de MongoDB.
#
# Vamos a ver un ejemplo de cómo utilizarlo.
#
# Vamos a encontrar el mínimo de $x^2$:
# (<a href="https://www.google.es/search?source=hp&ei=2ds5XO_jG6y_lwTvxp2QBQ&q=x**2&btnK=Google+Search&oq=x**2&gs_l=psy-ab.3...716.1584..1916...0.0..0.301.1084.1j0j3j1......0....1..gws-wiz.....0..0i131j0.cgRgMW95cQk">click aqui para ver la funcion</a>)

# %%
from hyperopt import fmin, tpe, hp
# con 10 iteraciones

best = fmin(fn=lambda x: x ** 2,
            space=hp.uniform('x', -10, 10),
            algo=tpe.suggest,
            max_evals=10)

print(best)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 537.43trial/s, best loss: 2.212401117457257]
# {'x': 1.4874142386898335}

# %%
# con 100 iteraciones
best = fmin(fn=lambda x: x ** 2,
            space=hp.uniform('x', -10, 10),
            algo=tpe.suggest,
            max_evals=100)

print(best)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 304.35trial/s, best loss: 7.987245874356897e-05]
# {'x': 0.00893713929306067}

# %%
# con 1000 iteraciones
best = fmin(fn=lambda x: x ** 2,
            space=hp.uniform('x', -10, 10),
            algo=tpe.suggest,
            max_evals=1000)

print(best)
# Out:
# 100%|██████████| 1000/1000 [00:15<00:00, 66.28trial/s, best loss: 1.319331445529426e-06]
# {'x': 0.0011486215414702207}

# %% [markdown]
# Y ahora uno más complejo con redes neuronales:

# %%
# instalamos los paquetes necesarios
# !pip install networkx
# !pip install hyperopt
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.3)
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.10/dist-packages (0.2.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from hyperopt) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from hyperopt) (1.11.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from hyperopt) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from hyperopt) (3.3)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from hyperopt) (0.18.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from hyperopt) (4.66.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from hyperopt) (2.2.1)
# Requirement already satisfied: py4j in /usr/local/lib/python3.10/dist-packages (from hyperopt) (0.10.9.7)

# %%
# imports necesarios
import sys
import time
import numpy as np
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.constraints import max_norm
from tensorflow.keras.optimizers.legacy import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.datasets import cifar10

SEED = 42

(X_train, y_train), (X_test, y_test) = cifar10.load_data()
validation_split = 0.1
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=validation_split, random_state=SEED)

# normalizamos
X_train = X_train.astype('float32') / 255.
X_val = X_val.astype('float32') / 255.
X_test = X_test.astype('float32') / 255.

# convertimos las etiquetas a one-hot encoding
n_classes = 10
y_train = to_categorical(y_train, n_classes)
y_val = to_categorical(y_val, n_classes)
y_test = to_categorical(y_test, n_classes)

# definimos nuestro espacio de búsqueda
# vamos a variar:
# - el número de filtros en nuestras capas conv
# - el porcentaje de dropout
# - el número de neuronas en la capa dense
space = {
    'n_filters_conv': hp.choice('n_filters_conv', [32, 64, 128]),
    'dropout': hp.uniform('dropout', 0.0, 0.5),
    'neurons_dense': hp.choice('neurons_dense', [256, 512, 1024]),
}

def	get_callbacks(pars):
  callbacks	= [EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=2, verbose=0, mode='auto')]
  return callbacks

def mi_cnn(pars):
  print ('Parameters: ', pars)
  model = Sequential()

  # Primer bloque convolucional
  model.add(Conv2D(pars['n_filters_conv'], kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(pars['dropout']))

  # Segundo bloque convolucional
  model.add(Conv2D(pars['n_filters_conv'], kernel_size=(3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(pars['dropout']))

  # Tercer bloque convolucional
  model.add(Conv2D(pars['n_filters_conv'], kernel_size=(3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(pars['dropout']))

  # Bloque clasificador
  model.add(Flatten())
  model.add(Dense(pars['neurons_dense'], activation='relu', kernel_constraint=max_norm(3.)))
  model.add(Dropout(pars['dropout']))
  model.add(Dense(10, activation='softmax'))

  # Compilamos el modelo
  model.compile(loss='categorical_crossentropy',
                optimizer=Adam(learning_rate=0.0001, decay=1e-6),
                metrics=['accuracy'])

  # Entrenamos el modelo
  history = model.fit(X_train,
                      y_train,
                      batch_size=128,
                      shuffle=True,
                      epochs=5,
                      validation_data=(X_val, y_val),
                      verbose = 0,
                      callbacks = get_callbacks(pars))

  best_epoch_loss = np.argmin(history.history['val_loss'])
  best_val_loss = np.min(history.history['val_loss'])
  best_val_acc = np.max(history.history['val_accuracy'])

  print('Epoch {} - val acc: {} - val loss: {}'.format(best_epoch_loss, best_val_acc, best_val_loss))
  sys.stdout.flush()

  return {'loss': best_val_loss, 'best_epoch': best_epoch_loss, 'eval_time': time.time(), 'status': STATUS_OK, 'model': model, 'history': history}


trials = Trials()
best = fmin(mi_cnn, space, algo=tpe.suggest, max_evals=10, trials=trials)
print(best)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 16s 0us/step
# Parameters:
# {'dropout': 0.17853520908195575, 'n_filters_conv': 32, 'neurons_dense': 256}
# Epoch 4 - val acc: 0.39640000462532043 - val loss: 1.6586565971374512
# Parameters:
# {'dropout': 0.3859553888023874, 'n_filters_conv': 64, 'neurons_dense': 512}
# Epoch 4 - val acc: 0.42579999566078186 - val loss: 1.5929936170578003
# Parameters:
# {'dropout': 0.40103881173321493, 'n_filters_conv': 64, 'neurons_dense': 512}
# Epoch 4 - val acc: 0.40939998626708984 - val loss: 1.6302917003631592
# Parameters:
# {'dropout': 0.07966907270916024, 'n_filters_conv': 128, 'neurons_dense': 1024}
# Epoch 4 - val acc: 0.5569999814033508 - val loss: 1.2723073959350586
# Parameters:
# {'dropout': 0.15484133742576117, 'n_filters_conv': 64, 'neurons_dense': 256}
# Epoch 4 - val acc: 0.46939998865127563 - val loss: 1.463975191116333
# Parameters:
# {'dropout': 0.21836569061993982, 'n_filters_conv': 64, 'neurons_dense': 256}
# Epoch 4 - val acc: 0.45899999141693115 - val loss: 1.50393545627594
# Parameters:
# {'dropout': 0.1950535557094324, 'n_filters_conv': 128, 'neurons_dense': 1024}
# Epoch 4 - val acc: 0.5447999835014343 - val loss: 1.2798274755477905
# Parameters:
# {'dropout': 0.46565699697933344, 'n_filters_conv': 64, 'neurons_dense': 1024}
# Epoch 4 - val acc: 0.4043999910354614 - val loss: 1.6552871465682983
# Parameters:
# {'dropout': 0.44888081787978595, 'n_filters_conv': 128, 'neurons_dense': 512}
# Epoch 4 - val acc: 0.462799996137619 - val loss: 1.5022732019424438
# Parameters:
# {'dropout': 0.11069691988707686, 'n_filters_conv': 128, 'neurons_dense': 512}
# Epoch 4 - val acc: 0.5407999753952026 - val loss: 1.3085843324661255
# 100%|██████████| 10/10 [04:33<00:00, 27.38s/trial, best loss: 1.2723073959350586]
# {'dropout': 0.07966907270916024, 'n_filters_conv': 2, 'neurons_dense': 2}

# %%
trials.trials
# Out:
# [{'state': 2,
#   'tid': 0,
#   'spec': None,
#   'result': {'loss': 1.6586565971374512,
#    'best_epoch': 4,
#    'eval_time': 1712934768.4170504,
#    'status': 'ok',
#    'model': <keras.src.engine.sequential.Sequential at 0x79cbf9a68940>,
#    'history': <keras.src.callbacks.History at 0x79cbf57414b0>},
#   'misc': {'tid': 0,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [0], 'n_filters_conv': [0], 'neurons_dense': [0]},
#    'vals': {'dropout': [0.17853520908195575],
#     'n_filters_conv': [0],
#     'neurons_dense': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 4, 12, 15, 12, 24, 520000),
#   'refresh_time': datetime.datetime(2024, 4, 12, 15, 12, 48, 417000)},
#  {'state': 2,
#   'tid': 1,
#   'spec': None,
#   'result': {'loss': 1.5929936170578003,
#    'best_epoch': 4,
#    'eval_time': 1712934791.1628962,
#    'status': 'ok',
#    'model': <keras.src.engine.sequential.Sequential at 0x79cbefe2cfa0>,
#    'history': <keras.src.callbacks.History at 0x79cbec500340>},
#   'misc': {'tid': 1,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [1], 'n_filters_conv': [1], 'neurons_dense': [1]},
#    'vals': {'dropout': [0.3859553888023874],
#     'n_filters_conv': [1],
#     'neurons_dense': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 4, 12, 15, 12, 48, 421000),
#   'refresh_time': datetime.datetime(2024, 4, 12, 15, 13, 11, 162000)},
#  {'state': 2,
#   'tid': 2,
#   'spec': None,
#   'result': {'loss': 1.6302917003631592,
#    'best_epoch': 4,
#    'eval_time': 1712934813.9101667,
#    'status': 'ok',
#    'model': <keras.src.engine.sequential.Sequential at 0x79cbec45f040>,
#    'history': <keras.src.callbacks.History at 0x79cbf0f4fbe0>},
#   'misc': {'tid': 2,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [2], 'n_filters_conv': [2], 'neurons_dense': [2]},
#    'vals': {'dropout': [0.40103881173321493],
#     'n_filters_conv': [1],
#     'neurons_dense': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 4, 12, 15, 13, 11, 167000),
#   'refresh_time': datetime.datetime(2024, 4, 12, 15, 13, 33, 910000)},
#  {'state': 2,
#   'tid': 3,
#   'spec': None,
#   'result': {'loss': 1.2723073959350586,
#    'best_epoch': 4,
#    'eval_time': 1712934842.7099383,
#    'status': 'ok',
#    'model': <keras.src.engine.sequential.Sequential at 0x79cbf05a96f0>,
#    'history': <keras.src.callbacks.History at 0x79cbf0508d90>},
#   'misc': {'tid': 3,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [3], 'n_filters_conv': [3], 'neurons_dense': [3]},
#    'vals': {'dropout': [0.07966907270916024],
#     'n_filters_conv': [2],
#     'neurons_dense': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 4, 12, 15, 13, 33, 916000),
#   'refresh_time': datetime.datetime(2024, 4, 12, 15, 14, 2, 709000)},
#  {'state': 2,
#   'tid': 4,
#   'spec': None,
#   'result': {'loss': 1.463975191116333,
#    'best_epoch': 4,
#    'eval_time': 1712934865.4429078,
#    'status': 'ok',
#    'model': <keras.src.engine.sequential.Sequential at 0x79cc903063e0>,
#    'history': <keras.src.callbacks.History at 0x79cbf0313d00>},
#   'misc': {'tid': 4,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [4], 'n_filters_conv': [4], 'neurons_dense': [4]},
#    'vals': {'dropout': [0.15484133742576117],
#     'n_filters_conv': [1],
#     'neurons_dense': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 4, 12, 15, 14, 2, 714000),
#   'refresh_time': datetime.datetime(2024, 4, 12, 15, 14, 25, 442000)},
#  {'state': 2,
#   'tid': 5,
#   'spec': None,
#   'result': {'loss': 1.50393545627594,
#    'best_epoch': 4,
#    'eval_time': 1712934888.222358,
#    'status': 'ok',
#    'model': <keras.src.engine.sequential.Sequential at 0x79cbf0328400>,
#    'history': <keras.src.callbacks.History at 0x79cbf00c8760>},
#   'misc': {'tid': 5,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [5], 'n_filters_conv': [5], 'neurons_dense': [5]},
#    'vals': {'dropout': [0.21836569061993982],
#     'n_filters_conv': [1],
#     'neurons_dense': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 4, 12, 15, 14, 25, 447000),
#   'refresh_time': datetime.datetime(2024, 4, 12, 15, 14, 48, 222000)},
#  {'state': 2,
#   'tid': 6,
#   'spec': None,
#   'result': {'loss': 1.2798274755477905,
#    'best_epoch': 4,
#    'eval_time': 1712934931.3656561,
#    'status': 'ok',
#    'model': <keras.src.engine.sequential.Sequential at 0x79cbf00ad750>,
#    'history': <keras.src.callbacks.History at 0x79cbec3659f0>},
#   'misc': {'tid': 6,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [6], 'n_filters_conv': [6], 'neurons_dense': [6]},
#    'vals': {'dropout': [0.1950535557094324],
#     'n_filters_conv': [2],
#     'neurons_dense': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 4, 12, 15, 14, 48, 227000),
#   'refresh_time': datetime.datetime(2024, 4, 12, 15, 15, 31, 365000)},
#  {'state': 2,
#   'tid': 7,
#   'spec': None,
#   'result': {'loss': 1.6552871465682983,
#    'best_epoch': 4,
#    'eval_time': 1712934948.2836177,
#    'status': 'ok',
#    'model': <keras.src.engine.sequential.Sequential at 0x79cbec29ae00>,
#    'history': <keras.src.callbacks.History at 0x79cbec315f30>},
#   'misc': {'tid': 7,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [7], 'n_filters_conv': [7], 'neurons_dense': [7]},
#    'vals': {'dropout': [0.46565699697933344],
#     'n_filters_conv': [1],
#     'neurons_dense': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 4, 12, 15, 15, 31, 370000),
#   'refresh_time': datetime.datetime(2024, 4, 12, 15, 15, 48, 283000)},
#  {'state': 2,
#   'tid': 8,
#   'spec': None,
#   'result': {'loss': 1.5022732019424438,
#    'best_epoch': 4,
#    'eval_time': 1712934991.4560788,
#    'status': 'ok',
#    'model': <keras.src.engine.sequential.Sequential at 0x79cbec367cd0>,
#    'history': <keras.src.callbacks.History at 0x79cbec0b3250>},
#   'misc': {'tid': 8,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [8], 'n_filters_conv': [8], 'neurons_dense': [8]},
#    'vals': {'dropout': [0.44888081787978595],
#     'n_filters_conv': [2],
#     'neurons_dense': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 4, 12, 15, 15, 48, 295000),
#   'refresh_time': datetime.datetime(2024, 4, 12, 15, 16, 31, 456000)},
#  {'state': 2,
#   'tid': 9,
#   'spec': None,
#   'result': {'loss': 1.3085843324661255,
#    'best_epoch': 4,
#    'eval_time': 1712935018.3513365,
#    'status': 'ok',
#    'model': <keras.src.engine.sequential.Sequential at 0x79cbec0cd1e0>,
#    'history': <keras.src.callbacks.History at 0x79cbe87870d0>},
#   'misc': {'tid': 9,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [9], 'n_filters_conv': [9], 'neurons_dense': [9]},
#    'vals': {'dropout': [0.11069691988707686],
#     'n_filters_conv': [2],
#     'neurons_dense': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 4, 12, 15, 16, 31, 461000),
#   'refresh_time': datetime.datetime(2024, 4, 12, 15, 16, 58, 351000)}]

# %% [markdown]
# ¿Por qué dice que best_epoch=4? Porque history está indexado en 0.

# %%
trials.trials[6]
# Out:
# {'state': 2,
#  'tid': 6,
#  'spec': None,
#  'result': {'loss': 1.2798274755477905,
#   'best_epoch': 4,
#   'eval_time': 1712934931.3656561,
#   'status': 'ok',
#   'model': <keras.src.engine.sequential.Sequential at 0x79cbf00ad750>,
#   'history': <keras.src.callbacks.History at 0x79cbec3659f0>},
#  'misc': {'tid': 6,
#   'cmd': ('domain_attachment', 'FMinIter_Domain'),
#   'workdir': None,
#   'idxs': {'dropout': [6], 'n_filters_conv': [6], 'neurons_dense': [6]},
#   'vals': {'dropout': [0.1950535557094324],
#    'n_filters_conv': [2],
#    'neurons_dense': [2]}},
#  'exp_key': None,
#  'owner': None,
#  'version': 0,
#  'book_time': datetime.datetime(2024, 4, 12, 15, 14, 48, 227000),
#  'refresh_time': datetime.datetime(2024, 4, 12, 15, 15, 31, 365000)}

# %%
trials.results
# Out:
# [{'loss': 1.6586565971374512,
#   'best_epoch': 4,
#   'eval_time': 1712934768.4170504,
#   'status': 'ok',
#   'model': <keras.src.engine.sequential.Sequential at 0x79cbf9a68940>,
#   'history': <keras.src.callbacks.History at 0x79cbf57414b0>},
#  {'loss': 1.5929936170578003,
#   'best_epoch': 4,
#   'eval_time': 1712934791.1628962,
#   'status': 'ok',
#   'model': <keras.src.engine.sequential.Sequential at 0x79cbefe2cfa0>,
#   'history': <keras.src.callbacks.History at 0x79cbec500340>},
#  {'loss': 1.6302917003631592,
#   'best_epoch': 4,
#   'eval_time': 1712934813.9101667,
#   'status': 'ok',
#   'model': <keras.src.engine.sequential.Sequential at 0x79cbec45f040>,
#   'history': <keras.src.callbacks.History at 0x79cbf0f4fbe0>},
#  {'loss': 1.2723073959350586,
#   'best_epoch': 4,
#   'eval_time': 1712934842.7099383,
#   'status': 'ok',
#   'model': <keras.src.engine.sequential.Sequential at 0x79cbf05a96f0>,
#   'history': <keras.src.callbacks.History at 0x79cbf0508d90>},
#  {'loss': 1.463975191116333,
#   'best_epoch': 4,
#   'eval_time': 1712934865.4429078,
#   'status': 'ok',
#   'model': <keras.src.engine.sequential.Sequential at 0x79cc903063e0>,
#   'history': <keras.src.callbacks.History at 0x79cbf0313d00>},
#  {'loss': 1.50393545627594,
#   'best_epoch': 4,
#   'eval_time': 1712934888.222358,
#   'status': 'ok',
#   'model': <keras.src.engine.sequential.Sequential at 0x79cbf0328400>,
#   'history': <keras.src.callbacks.History at 0x79cbf00c8760>},
#  {'loss': 1.2798274755477905,
#   'best_epoch': 4,
#   'eval_time': 1712934931.3656561,
#   'status': 'ok',
#   'model': <keras.src.engine.sequential.Sequential at 0x79cbf00ad750>,
#   'history': <keras.src.callbacks.History at 0x79cbec3659f0>},
#  {'loss': 1.6552871465682983,
#   'best_epoch': 4,
#   'eval_time': 1712934948.2836177,
#   'status': 'ok',
#   'model': <keras.src.engine.sequential.Sequential at 0x79cbec29ae00>,
#   'history': <keras.src.callbacks.History at 0x79cbec315f30>},
#  {'loss': 1.5022732019424438,
#   'best_epoch': 4,
#   'eval_time': 1712934991.4560788,
#   'status': 'ok',
#   'model': <keras.src.engine.sequential.Sequential at 0x79cbec367cd0>,
#   'history': <keras.src.callbacks.History at 0x79cbec0b3250>},
#  {'loss': 1.3085843324661255,
#   'best_epoch': 4,
#   'eval_time': 1712935018.3513365,
#   'status': 'ok',
#   'model': <keras.src.engine.sequential.Sequential at 0x79cbec0cd1e0>,
#   'history': <keras.src.callbacks.History at 0x79cbe87870d0>}]

# %%
trials.losses()
# Out:
# [1.6586565971374512,
#  1.5929936170578003,
#  1.6302917003631592,
#  1.2723073959350586,
#  1.463975191116333,
#  1.50393545627594,
#  1.2798274755477905,
#  1.6552871465682983,
#  1.5022732019424438,
#  1.3085843324661255]

# %% [markdown]
# Qué os parece? mola eh? Así, podéis dejar vuestra configuración e iros a hacer algo más útil que andar variando parámetros hasta que encontréis la configuración adecuada.
#
# **Mejor que lo hagan por nosotros y que nos la encontremos automáticamente seleccionada!**
#
# Pero no tenemos por qué quedarnos aquí, podemos también variar el número de capas o si queremos conexiones residuales, por ejemplo! Sí, esto significa que podemos variar la **arquitectura** también!!
#
# Aquí tenéis un ejemplo muy completo: https://github.com/Vooban/Hyperopt-Keras-CNN-CIFAR-100
#
# Y aquí otro que quizá os parezca interesante:
#
# <img src="http://cdn.lizamayliza.com/storage/cache/images/003/636/Daffy-Duck-Money-eyes-feature,xlarge.1480369578.jpg" border="0" height="200">
#
# https://medium.com/machine-learning-world/neural-networks-for-algorithmic-trading-hyperparameters-optimization-cb2b4a29b8ee

# %% [markdown]
# ## 6.3 Algoritmos genéticos
#
# Quizás estéis pensando en que tras haber visto esto no necesitáis saber nada más, ya habéis encontrado algo que es la repera! Pues atentos porque lo que viene, pese a ser algo muy sencillo, es potentísimo, y os va encantar. Sí, estoy hablando de **los algoritmos genéticos**.
#
# En esencia, los algoritmos genéticos son un método de búsqueda meta-heurística inspirados en la evolución natural. Pertenecen a los algoritmos evolutivos, concretamente a los Algoritmos de búsqueda aleatoria guiada (Guided Random Search algorithms (Evolutionary Alg.)).
#
# Esto que os puede parecer chino, es muy sencillo. Vamos a entenderlos con un ejemplo:
#
# <img src="https://image.ibb.co/cJcQYJ/ga_problem.png" alt="ga_problem" border="0">
#
# Imaginad que tenemos un puzzle, y nos queda solo una pieza por encajar. Lo que pasa es que este puzzle es muy especial, porque nos permite fabricarnos nuestras propias piezas. Para ello, disponemos de varios mecanismos:
#
# * **combinar** partes de piezas (**crossover** o recombinación)
# * **modificar** determinadas partes de esas piezas (**mutación**)
# * **escoger** las mejores piezas de todas las que hemos hecho, para a partir de ellas, construir nuevas que sean mejores (**selección**)
#
# Entonces imaginaos que decidimos cortar 10 trozos de carton, que son nuestras 10 piezas iniciales con las que vamos a probar a ver si alguna encaja perfectamnte. Las probamos todas, y de esas 10, 5 encajan más o menos. Así que seleccionamos esas 5 y fabricamos nuevas a partir de ellas mediante los mecanismos explicados arriba:
#
# * de las 5 seleccionadas, sacamos 5 más combinando partes de dos de esas 5 originales escogiéndolas aleatoriamente
# * de las 5 originales, y las nuevas 5 que nos hemos creado, sacamos 5 más modificando ligeramente una de las puntas de la pieza
#
# Ahora resulta que tenemos 15 piezas, y nosotros queremos tener siempre 10, porque si no a la 5 vez que hiciéramos esto tendríamos una barbaridad de piezas!! Así que:
#
# * probamos nuestras 15 piezas y nos quedamos con la que mejor encaja, y luego 9 escogidas al azar
#
# Pues ya está, eso es lo que hace un algoritmo genético!! Ya sabéis cómo funcionan!! Sencillo, verdad? Pues no os hacéis una idea de lo potentes que son :-)
#
# Vamos a verlo un poco más concreto siguiendo con nuestro ejemplo:
#
# <img src="https://image.ibb.co/b7ySfy/geneticos_puzzle.png" alt="geneticos_puzzle" border="0">
#
# Como podéis ver:
#
# * cada pieza de nuestro conjunto de piezas (población) es un **cromosoma**
# * cada parte de nuestra pieza es un **gen**, por tanto, nuestro cromosoma tiene 4 genes
# * los posibles valores o configuraciones que puede tener cada gen se llama **alelo**
#
# Esto es exactamente igual que en biología! No os dije que estaban inspirados en la evolución natural? :-)
#
# Vale, pues vamos a ir relacionando estas palabrejas con nuestro ejemplo:
#
# * necesitamos encontrar la pieza correcta para nuestro hueco del puzzle
# * tenemos un conjunto inicial de piezas (**población**) que pueden encajar bien o no, no lo sabemos
# * comprobamos cómo de bien encajan estas piezas (usando la **función de fitness**)
# * si ninguna de las piezas encaja como nos gustaría, modificamos las piezas (con los operadores: **crossover** y **mutación**)
# * comprobamos como de bien encajan las piezas recien creadas (**función de fitness**)
# * seleccionamos las piezas que queremos aguantar para la próxima iteración (**selección**)
#
# * y volvemos a empezar! así, hasta que enocntremos una pieza que encaje con la precisión que nosotros queremos
#
# Venga, vamos a ponernos un poco más serios. Veamos el pseudo-algoritmo:
#
# **START**
#
# Generate the initial population
#
# Compute fitness
#
# **REPEAT**
#
#     Selection
#
#     Crossover
#
#     Mutation
#
#     Compute fitness
#
# **UNTIL** population has converged
#
# **STOP**
#
# Se entiende, no? Es exactamente lo mismo que los pasos que acabamos de hablar con el puzzle!!
#
# <img src="https://image.ibb.co/kQu7Ed/ga_workflow.png" alt="ga_workflow" border="0" width="600">
#
# Vale, y ahora llega lo interesante, cómo funcionan realmente?
#
# Tenemos que entender varios conceptos:
#
# * cómo se inicializa nuestra población
# * cómo funciona el crossover
# * cómo funciona la mutación
# * cómo funciona la seleccion
# * cómo podemos definir nuestra función de fitness
#
# Preparados? Vamos allá!

# %% [markdown]
# Lo primero es entender que cuando tenemos un problema en el mundo real y queremos solucionarlo en un ordenador, necesitamos **codificarlo** para que el ordenador lo entienda.
#
# Así, por ejemplo:
#
# * En el mundo real, el cromosoma es la pieza del puzzle. En el ordenador, el cromosoma es un vector con 4 valores (uno para indicar el tamaño de cada punta, donde positivo significa punta, negativo significa hueco hacia dentro de la pieza)
#
# Esto es a lo que se llama la codificación.
#
# Una vez sabido esto, vamos a ver cómo funcionan los operadores. Antes de nada, debéis saber que xisten muchos tipos de crossover, mutación y selección, pero aquí vamos a ver solo los más sencillos por temas de tiempo.
#
# Si estáis interesados en conocerlos más profundamente, en internet hay muchísimo material disponible. Podéis empezar aquí: https://www.tutorialspoint.com/genetic_algorithms/index.htm
#
# Vale, al turrón!
#
# <img src="https://image.ibb.co/hEwVHd/ga_operators.png" alt="ga_operators" border="0">
#
# **El crossover de un único punto (single-point crossover)**
#
# Nuestro cromosoma es la pieza de puzzle, que tiene los 4 genes que veis en la imagen. Pues el crossover simple sencillamente escoge un punto aleatoriamente de los 4 genes, y combina las partes en nuevos cromosomas, como veis en la imagen.
#
# Es importante que entendáis que el crossover **produce nuevos cromosomas**, puesto que tenemos los originales y los **recombinados**.
#
# **La mutación uniforme**
#
# La mutación uniforme consiste en que para cada cromosoma, lanzamos una moneda al aire. Si sale cara, modificamos un gen escogido aleatoriamente. ¿Qué valor le asignamos? Uno aleatorio dentro del rango que permite dicho gen.
#
# **La selección**
#
# Para la selección lo que se suele hacer es usar las fitness de los cromosomas (también llamados posibles **soluciones**). En este caso, vamos a ver la Stochastic Universal Sampling, que consiste en que construímos una gráfica de tipo tarta donde cada cromosoma ocupa un espacio que corresponde con su fitness. Después, establecemos N puntos fijos alrededor de la "tarta", donde N son el número de cromomsomas que queremos **seleccionar**. Después, se "gira la tarta", como si fuese la ruleta de la suerte, y los cromosomas a los que apuntan los puntos fijos son los seleccionados y pasan a la siguiente iteración.
#
# Si os fijáis, **los cromosomas no están ordenados de mayor a menor fitness**!!
#
# Esto es importante, puesto que si no, las probabilidades de seleccionar un cromosoma con una fitness alta y otro con una fitness baja serían más altas que de seleccionar dos con la fitness alta, ya que al estar los puntos de selección uno enfrente del otro, sería muy complicado seleccionar dos cromosomas con fitness parecidas.
#
# Este operador tiene varias formas de funcionar. Siguiendo con nuestro ejemplo de población de 10 cromosomas, las formas son:
#
# * Seleccionamos $N=10$ cromosomas, es decir, sustituimos la anterior población por una completamente nueva
# * Seleccionamos $N=n$ cromosomas, donde n<10. Es decir, sustituímos solo una parte de los crosomomas antiguos. El resto siguen jugando ;-D
#
# Vale, pues si seleccionamos los 10 está claro, pero si seleccionamos $n$, cómo elegimos cuales quitamos?
#
# Pues las dos formas más comunes son:
#
# * Quitamos los cromosomas más antiguos
# * Quitamos los cromosomas con peor fitness
#
# Ya por último, hay veces que seleccionamos al mejor cromosoma (o a los $k$ mejors) para que pase si o si a la siguiente iteración, es decir, hay *elitismo*. Hay que ir con cuidado con esto, puesto que aunque a priori parezca que el elitismo es lo mejor y que solo deberíamos quedarnos con los mejores, si lo hiciésemos nos estaríamos cargando una de las mayores virtudes de los genéticos: **que son capaces de escapar a mínimos locales!!!**
#
# Fijaos, aquí podéis ver en plena acción a un genético intentando decidir cual es la mejor configuración para un vehículo de 2 ruedas: http://rednuht.org/genetic_cars_2/
#
# Curioso, eh?
#
# Vale, pues ahora qué tal si implementamos un par de ejemplos nosotros?

# %%
# ejemplo simple de un GA donde tenemos que encontrar N números que sumen X
# https://lethain.com/genetic-algorithms-cool-name-damn-simple

from random import randint, random
from operator import add
from functools import reduce
import numpy as np

def individual(length, min, max):
    # creamos un individuo
    return [ randint(min,max) for x in range(length) ]

def population(count, length, min, max):
    # creamos nuestra población
    # count: numero de invidiuos en la población
    # length: número de valores por individuo
    # min: minimo permitido para cada valor del individuo
    # max: maximo permitido para cada valor del individuo

    return [ individual(length, min, max) for x in range(count) ]

def fitness(individual, target):
    # calculamos la fitness de un individuo: más bajo es mejor

    sum = reduce(add, individual, 0)
    return abs(target-sum)

def grade(pop, target):
    # calculamos la media de la población entera
    summed = reduce(add, (fitness(x, target) for x in pop))
    return summed / (len(pop) * 1.0)

def find_best_solution(pop, target):
    # encuentra la mejor solución en la población actual y la imprime
    res = [fitness(x, target) for x in pop]
    res_min = np.min(res)
    res_min_idx = np.where(res == res_min)[0]
    for n in res_min_idx:
        print('Individual: ', n, 'Valores: ', *pop[n], ' Result: ', np.sum(pop[n]), 'Target; ', target)
    return res_min

def evolve(pop, target, retain=0.2, random_select=0.05, mutate=0.01):
    graded = [ (fitness(x, target), x) for x in pop]
    graded = [ x[1] for x in sorted(graded)]
    retain_length = int(len(graded)*retain)
    parents = graded[:retain_length]

    # añadimos individuos aleatoriamente para promover la diversidad genética
    for individual in graded[retain_length:]:
        if random_select > random():
            parents.append(individual)

    # mutamos algunos
    for individual in parents:
        if mutate > random():
            pos_to_mutate = randint(0, len(individual)-1)
            individual[pos_to_mutate] = randint(i_min, i_max)

    # reproducimos (crossover) nuestros cromosomas (individuals, soluciones)
    parents_length = len(parents)
    desired_length = len(pop) - parents_length
    children = []
    while len(children) < desired_length:
        male = randint(0, parents_length-1)
        female = randint(0, parents_length-1)
        if male != female:
            male = parents[male]
            female = parents[female]
            half = round(len(male) / 2)
            child = male[:half] + female[half:]
            children.append(child)
    parents.extend(children)
    return parents

# ejecutamos el GA
generations = 200
target = 108
p_count = 20
i_length = 10
i_min = 0
i_max = 100
error_accepted = 1
print('Inicializamos la población con 20 individuos.')
p = population(p_count, i_length, i_min, i_max)
print('Calculamos el fitness de esos 20 individuos.')
fitness_history = [grade(p, target),]
print('El mejor individuo de la población inicial es:')
find_best_solution(p, target)

print('Comienza la búsqueda:')
for i in range(generations):
    p = evolve(p, target, retain=0.2, random_select=0.4, mutate=0.4)
    res = grade(p, target)
    fitness_history.append(res)

    res_min = find_best_solution(p, target)
    print('Generación: ', i, ' Fitness medio de todos los individuos de la población:', res)

    if res_min < error_accepted:
      break
# Out:
# Inicializamos la población con 20 individuos.
# Calculamos el fitness de esos 20 individuos.
# El mejor individuo de la población inicial es:
# Individual:  13 Valores:  2 54 80 20 46 13 35 47 4 2  Result:  303 Target;  108
# Comienza la búsqueda:
# Individual:  9 Valores:  62 6 20 65 41 13 35 47 4 2  Result:  295 Target;  108
# Generación:  0  Fitness medio de todos los individuos de la población: 302.85
# Individual:  17 Valores:  55 20 1 83 24 13 35 47 4 2  Result:  284 Target;  108
# Generación:  1  Fitness medio de todos los individuos de la población: 256.25
# Individual:  0 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Generación:  2  Fitness medio de todos los individuos de la población: 262.9
# Individual:  0 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Generación:  3  Fitness medio de todos los individuos de la población: 244.5
# Individual:  0 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Individual:  15 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Generación:  4  Fitness medio de todos los individuos de la población: 236.2
# Individual:  1 Valores:  18 20 1 22 24 13 35 47 4 2  Result:  186 Target;  108
# Generación:  5  Fitness medio de todos los individuos de la población: 251.45
# Individual:  0 Valores:  18 20 1 22 24 13 35 47 4 2  Result:  186 Target;  108
# Generación:  6  Fitness medio de todos los individuos de la población: 230.65
# Individual:  18 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Generación:  7  Fitness medio de todos los individuos de la población: 243.7
# Individual:  0 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Individual:  14 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Individual:  16 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Generación:  8  Fitness medio de todos los individuos de la población: 237.5
# Individual:  0 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Individual:  1 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Individual:  2 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Individual:  15 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Individual:  17 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Individual:  18 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Generación:  9  Fitness medio de todos los individuos de la población: 235.05
# Individual:  0 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Individual:  1 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Individual:  2 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Individual:  12 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Individual:  15 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Individual:  16 Valores:  18 20 1 83 24 13 35 47 4 2  Result:  247 Target;  108
# Generación:  10  Fitness medio de todos los individuos de la población: 222.6
# Individual:  1 Valores:  18 5 1 83 24 13 35 47 4 2  Result:  232 Target;  108
# Individual:  8 Valores:  18 5 1 83 24 13 35 47 4 2  Result:  232 Target;  108
# Individual:  12 Valores:  18 5 1 83 24 13 35 47 4 2  Result:  232 Target;  108
# Individual:  14 Valores:  18 5 1 83 24 13 35 47 4 2  Result:  232 Target;  108
# Generación:  11  Fitness medio de todos los individuos de la población: 189.4
# Individual:  4 Valores:  18 20 1 11 24 13 35 47 4 2  Result:  175 Target;  108
# Generación:  12  Fitness medio de todos los individuos de la población: 202.9
# Individual:  0 Valores:  18 20 1 11 24 13 35 47 4 2  Result:  175 Target;  108
# Individual:  15 Valores:  18 20 1 11 24 13 35 47 4 2  Result:  175 Target;  108
# Generación:  13  Fitness medio de todos los individuos de la población: 179.75
# Individual:  0 Valores:  18 20 1 11 24 13 35 47 4 2  Result:  175 Target;  108
# Individual:  1 Valores:  18 20 1 11 24 13 35 47 4 2  Result:  175 Target;  108
# Individual:  17 Valores:  18 20 1 11 24 13 35 47 4 2  Result:  175 Target;  108
# Generación:  14  Fitness medio de todos los individuos de la población: 169.35
# Individual:  0 Valores:  18 20 1 11 24 13 35 47 4 2  Result:  175 Target;  108
# Individual:  1 Valores:  18 20 1 11 24 13 35 47 4 2  Result:  175 Target;  108
# Individual:  2 Valores:  18 20 1 11 24 13 35 47 4 2  Result:  175 Target;  108
# Generación:  15  Fitness medio de todos los individuos de la población: 144.8
# Individual:  19 Valores:  18 20 1 11 24 13 26 47 4 2  Result:  166 Target;  108
# Generación:  16  Fitness medio de todos los individuos de la población: 141.85
# Individual:  14 Valores:  18 20 1 11 24 13 5 47 4 2  Result:  145 Target;  108
# Generación:  17  Fitness medio de todos los individuos de la población: 121.15
# Individual:  0 Valores:  18 22 1 11 24 13 5 47 4 2  Result:  147 Target;  108
# Generación:  18  Fitness medio de todos los individuos de la población: 112.3
# Individual:  15 Valores:  14 20 1 11 24 13 5 47 4 2  Result:  141 Target;  108
# Generación:  19  Fitness medio de todos los individuos de la población: 94.0
# Individual:  0 Valores:  14 20 1 11 24 13 5 47 4 2  Result:  141 Target;  108
# Individual:  14 Valores:  14 20 1 11 24 13 5 47 4 2  Result:  141 Target;  108
# Generación:  20  Fitness medio de todos los individuos de la población: 77.5
# Individual:  0 Valores:  14 20 1 11 24 13 5 47 4 2  Result:  141 Target;  108
# Individual:  1 Valores:  14 20 1 11 24 13 5 47 4 2  Result:  141 Target;  108
# Generación:  21  Fitness medio de todos los individuos de la población: 76.5
# Individual:  4 Valores:  18 22 1 11 24 13 5 18 4 2  Result:  118 Target;  108
# Generación:  22  Fitness medio de todos los individuos de la población: 74.35
# Individual:  0 Valores:  18 22 1 11 24 13 5 18 4 2  Result:  118 Target;  108
# Generación:  23  Fitness medio de todos los individuos de la población: 70.9
# Individual:  0 Valores:  18 22 1 11 24 13 5 18 4 2  Result:  118 Target;  108
# Generación:  24  Fitness medio de todos los individuos de la población: 83.35
# Individual:  12 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Individual:  19 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Generación:  25  Fitness medio de todos los individuos de la población: 96.65
# Individual:  0 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Individual:  1 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Individual:  5 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Individual:  8 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Individual:  10 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Generación:  26  Fitness medio de todos los individuos de la población: 62.7
# Individual:  0 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Individual:  1 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Individual:  2 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Individual:  3 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Individual:  10 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Individual:  13 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Individual:  19 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Generación:  27  Fitness medio de todos los individuos de la población: 62.9
# Individual:  2 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Individual:  3 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Individual:  15 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Individual:  18 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Generación:  28  Fitness medio de todos los individuos de la población: 76.85
# Individual:  14 Valores:  13 20 1 11 24 13 5 18 4 2  Result:  111 Target;  108
# Generación:  29  Fitness medio de todos los individuos de la población: 56.75
# Individual:  3 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Individual:  17 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Generación:  30  Fitness medio de todos los individuos de la población: 49.35
# Individual:  0 Valores:  14 20 1 11 24 13 5 18 4 2  Result:  112 Target;  108
# Generación:  31  Fitness medio de todos los individuos de la población: 68.2
# Individual:  11 Valores:  13 20 1 11 24 13 5 18 4 2  Result:  111 Target;  108
# Generación:  32  Fitness medio de todos los individuos de la población: 93.25
# Individual:  0 Valores:  13 20 1 11 24 13 5 18 4 2  Result:  111 Target;  108
# Individual:  14 Valores:  13 20 1 11 24 13 5 18 4 2  Result:  111 Target;  108
# Generación:  33  Fitness medio de todos los individuos de la población: 97.95
# Individual:  2 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Individual:  3 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Individual:  17 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Generación:  34  Fitness medio de todos los individuos de la población: 97.85
# Individual:  1 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Individual:  2 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Individual:  15 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Generación:  35  Fitness medio de todos los individuos de la población: 104.1
# Individual:  1 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Individual:  2 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Individual:  9 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Individual:  11 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Individual:  13 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Individual:  18 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Generación:  36  Fitness medio de todos los individuos de la población: 65.65
# Individual:  0 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Individual:  1 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Generación:  37  Fitness medio de todos los individuos de la población: 93.1
# Individual:  1 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Individual:  18 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Individual:  19 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Generación:  38  Fitness medio de todos los individuos de la población: 88.5
# Individual:  1 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Individual:  13 Valores:  15 20 1 11 24 13 5 18 4 2  Result:  113 Target;  108
# Generación:  39  Fitness medio de todos los individuos de la población: 101.35
# Individual:  1 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  10 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Generación:  40  Fitness medio de todos los individuos de la población: 109.1
# Individual:  0 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  1 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  9 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Generación:  41  Fitness medio de todos los individuos de la población: 116.0
# Individual:  1 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  14 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Generación:  42  Fitness medio de todos los individuos de la población: 124.8
# Individual:  0 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  15 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Generación:  43  Fitness medio de todos los individuos de la población: 112.85
# Individual:  2 Valores:  15 21 1 22 24 13 5 18 4 2  Result:  125 Target;  108
# Individual:  16 Valores:  15 21 1 22 24 13 5 18 4 2  Result:  125 Target;  108
# Generación:  44  Fitness medio de todos los individuos de la población: 128.65
# Individual:  10 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  11 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Generación:  45  Fitness medio de todos los individuos de la población: 102.95
# Individual:  1 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  11 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  16 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  17 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  18 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Generación:  46  Fitness medio de todos los individuos de la población: 57.65
# Individual:  1 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  2 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  3 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  13 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  17 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Generación:  47  Fitness medio de todos los individuos de la población: 57.15
# Individual:  8 Valores:  8 20 1 22 24 13 5 18 4 2  Result:  117 Target;  108
# Generación:  48  Fitness medio de todos los individuos de la población: 59.8
# Individual:  3 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  4 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  9 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  10 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  18 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Generación:  49  Fitness medio de todos los individuos de la población: 48.05
# Individual:  1 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  2 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  3 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  13 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  17 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  18 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  19 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Generación:  50  Fitness medio de todos los individuos de la población: 41.55
# Individual:  0 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  1 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  9 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  13 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Generación:  51  Fitness medio de todos los individuos de la población: 40.95
# Individual:  0 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  3 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  12 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  16 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  17 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Generación:  52  Fitness medio de todos los individuos de la población: 66.6
# Individual:  0 Valores:  15 20 1 22 4 13 5 18 4 2  Result:  104 Target;  108
# Generación:  53  Fitness medio de todos los individuos de la población: 70.85
# Individual:  4 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  12 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Individual:  13 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Generación:  54  Fitness medio de todos los individuos de la población: 91.75
# Individual:  16 Valores:  15 20 1 22 4 13 5 18 4 2  Result:  104 Target;  108
# Generación:  55  Fitness medio de todos los individuos de la población: 98.75
# Individual:  14 Valores:  15 20 1 22 24 13 5 18 4 2  Result:  124 Target;  108
# Generación:  56  Fitness medio de todos los individuos de la población: 115.05
# Individual:  10 Valores:  15 20 1 22 4 13 5 18 4 2  Result:  104 Target;  108
# Generación:  57  Fitness medio de todos los individuos de la población: 92.65
# Individual:  2 Valores:  15 20 1 22 4 37 5 0 4 2  Result:  110 Target;  108
# Generación:  58  Fitness medio de todos los individuos de la población: 66.95
# Individual:  13 Valores:  15 20 1 2 4 37 5 18 4 2  Result:  108 Target;  108
# Generación:  59  Fitness medio de todos los individuos de la población: 89.65

# %%
# Ejemplo un poco más complejo de un GA que tiene que encontrar la cadena 'Hello Word!'
# http://www.obitko.com/tutorials/genetic-algorithms/ga-basic-description.php

import random

class GeneticAlgorithm(object):
    def __init__(self, genetics):
        self.genetics = genetics
        pass

    def run(self):
        population = self.genetics.initial()
        while True:
            fits_pops = [(self.genetics.fitness(ch),  ch) for ch in population]
            if self.genetics.check_stop(fits_pops): break
            population = self.next(fits_pops)
            pass
        return population

    def next(self, fits):
        parents_generator = self.genetics.parents(fits)
        size = len(fits)
        nexts = []
        while len(nexts) < size:
            parents = next(parents_generator)
            cross = random.random() < self.genetics.probability_crossover()
            children = self.genetics.crossover(parents) if cross else parents
            for ch in children:
                mutate = random.random() < self.genetics.probability_mutation()
                nexts.append(self.genetics.mutation(ch) if mutate else ch)
                pass
            pass
        return nexts[0:size]
    pass

class GeneticFunctions(object):
    def probability_crossover(self):
        # returns rate of occur crossover(0.0-1.0)
        return 1.0

    def probability_mutation(self):
        # returns rate of occur mutation(0.0-1.0)
        return 0.0

    def initial(self):
        # returns list of initial population
        return []

    def fitness(self, chromosome):
        # returns domain fitness value of chromosome
        return len(chromosome)

    def check_stop(self, fits_populations):
        # stop run if returns True
        # - fits_populations: list of (fitness_value, chromosome)
        return False

    def parents(self, fits_populations):
        r"""generator of selected parents
        """
        gen = iter(sorted(fits_populations))
        while True:
            f1, ch1 = next(gen)
            f2, ch2 = next(gen)
            yield (ch1, ch2)
            pass
        return

    def crossover(self, parents):
        r"""breed children
        """
        return parents

    def mutation(self, chromosome):
        r"""mutate chromosome
        """
        return chromosome
    pass

if __name__ == "__main__":
    """
    example: Mapped guess prepared Text
    """
    class GuessText(GeneticFunctions):
        def __init__(self, target_text,
                     limit=200, size=400,
                     prob_crossover=0.9, prob_mutation=0.2):
            self.target = self.text2chromo(target_text)
            self.counter = 0

            self.limit = limit
            self.size = size
            self.prob_crossover = prob_crossover
            self.prob_mutation = prob_mutation
            pass

        # GeneticFunctions interface impls
        def probability_crossover(self):
            return self.prob_crossover

        def probability_mutation(self):
            return self.prob_mutation

        def initial(self):
            return [self.random_chromo() for j in range(self.size)]

        def fitness(self, chromo):
            # larger is better, matched == 0
            return -sum(abs(c - t) for c, t in zip(chromo, self.target))

        def check_stop(self, fits_populations):
            self.counter += 1
            if self.counter % 1 == 0:
                best_match = list(sorted(fits_populations))[-1][1]
                fits = [f for f, ch in fits_populations]
                best = max(fits)
                worst = min(fits)
                ave = sum(fits) / len(fits)
                print(
                    "[G %3d] score=(%4d, %4d, %4d): %r" %
                    (self.counter, best, ave, worst,
                     self.chromo2text(best_match)))
                pass
            return self.counter >= self.limit

        def parents(self, fits_populations):
            while True:
                father = self.tournament(fits_populations)
                mother = self.tournament(fits_populations)
                yield (father, mother)
                pass
            pass

        def crossover(self, parents):
            father, mother = parents
            index1 = random.randint(1, len(self.target) - 2)
            index2 = random.randint(1, len(self.target) - 2)
            if index1 > index2: index1, index2 = index2, index1
            child1 = father[:index1] + mother[index1:index2] + father[index2:]
            child2 = mother[:index1] + father[index1:index2] + mother[index2:]
            return (child1, child2)

        def mutation(self, chromosome):
            index = random.randint(0, len(self.target) - 1)
            vary = random.randint(-5, 5)
            mutated = list(chromosome)
            mutated[index] += vary
            return mutated

        # internals
        def tournament(self, fits_populations):
            alicef, alice = self.select_random(fits_populations)
            bobf, bob = self.select_random(fits_populations)
            return alice if alicef > bobf else bob

        def select_random(self, fits_populations):
            return fits_populations[random.randint(0, len(fits_populations)-1)]

        def text2chromo(self, text):
            return [ord(ch) for ch in text]
        def chromo2text(self, chromo):
            return "".join(chr(max(1, min(ch, 255))) for ch in chromo)

        def random_chromo(self):
            return [random.randint(1, 255) for i in range(len(self.target))]
        pass

    GeneticAlgorithm(GuessText("Hello World!")).run()
    pass
# Out:
# [G   1] score=(-375, -866, -1333): '\x8akq»U+6=(l\\2'
# [G   2] score=(-331, -786, -1160): '\x10ihbQ6:@\x7f^\x88c'
# [G   3] score=(-331, -707, -1057): '\x10ihbQ6:@\x7f^\x88c'
# [G   4] score=(-327, -636, -946): '\x0fihbV6:@\x7f^\x88c'
# [G   5] score=(-323, -566, -900): '\x10s^H\x90\x1dB\x88w^\x88c'
# [G   6] score=(-269, -504, -828): 'RQPr`\x1f\x18\x8c\x7f\x7fDB'
# [G   7] score=(-206, -459, -808): 'RQPr`\x1fmhwRCB'
# [G   8] score=(-178, -413, -614): 'TihbeHmh\x7f^>\x1d'
# [G   9] score=(-151, -374, -562): 'Tihbe\nLx\x7f^>\x1d'
# [G  10] score=(-147, -334, -515): 'Tilbe\nLx\x7f^>\x1d'
# [G  11] score=(-137, -302, -473): 'Tijwk@Un\x7f^>\x1d'
# [G  12] score=(-117, -269, -406): 'Td}uf\x1dVnw^;\x1d'
# [G  13] score=(-135, -242, -375): 'Ishqk\x1f:ny\x89\x82\x17'
# [G  14] score=(-124, -217, -321): 'Ishkf\x19UcwO\x82\x17'
# [G  15] score=( -95, -194, -307): 'Iierj\x1dSnw\x84\x82\x1c'
# [G  16] score=(-104, -175, -261): 'Tijbk\x1dLns^>\x1d'
# [G  17] score=( -86, -157, -243): 'Ijeko#Unw\x86\x82\x1c'
# [G  18] score=( -85, -141, -220): 'Idlbo\x1dUn\x7f^\x82\x17'
# [G  19] score=( -77, -128, -220): 'Idlbo\x1dUnw^\x82\x17'
# [G  20] score=( -77, -114, -170): 'Iilco\x1fUnv^\x83\x17'
# [G  21] score=( -76, -104, -151): 'Idlqo\x1eUnw\x84}\x17'
# [G  22] score=( -68,  -96, -143): 'Idlko\x1dUnw^\x82\x17'
# [G  23] score=( -68,  -90, -134): 'Ikmko#Tmt^}\x17'
# [G  24] score=( -66,  -84, -116): 'Idjko#Uot^\x82\x17'
# [G  25] score=( -60,  -79, -105): 'Iijko#Unt^\x82!'
# [G  26] score=( -60,  -75, -102): 'Iijko#Unt^\x82!'
# [G  27] score=( -60,  -72,  -93): 'Iijko#Unt^\x82!'
# [G  28] score=( -56,  -69,  -87): 'Iijko\x1fWnt^\x82!'
# [G  29] score=( -54,  -67,  -81): 'Iilko\x1fWnt^\x82!'
# [G  30] score=( -53,  -64,  -77): 'Iilko\x1fWot^\x82!'
# [G  31] score=( -49,  -62,  -73): 'Idlko\x1fUnt^~!'
# [G  32] score=( -48,  -60,  -72): 'Idjko Xntc\x82!'
# [G  33] score=( -44,  -58,  -73): 'Idlko Untb~!'
# [G  34] score=( -42,  -55,  -69): 'Idlko Wntb~!'
# [G  35] score=( -41,  -53,  -66): 'Iflko Untb{!'
# [G  36] score=( -41,  -52,  -61): 'Iflko Untb{!'
# [G  37] score=( -39,  -50,  -59): 'Iflko Wntb{!'
# [G  38] score=( -38,  -48,  -60): 'Idljo Xnth~!'
# [G  39] score=( -37,  -47,  -56): 'Idlko Xnth~!'
# [G  40] score=( -37,  -45,  -57): 'Idllo\x1fWntby!'
# [G  41] score=( -35,  -44,  -58): 'Iflko Xnth|!'
# [G  42] score=( -35,  -42,  -52): 'Ihllo\x1fXntgy!'
# [G  43] score=( -33,  -41,  -51): 'Ielko\x1fWoth|!'
# [G  44] score=( -31,  -40,  -50): 'Idlko Wnthy!'
# [G  45] score=( -31,  -39,  -50): 'Idlko Wnthy!'
# [G  46] score=( -31,  -38,  -48): 'Iello Wntfy!'
# [G  47] score=( -28,  -36,  -48): 'Idlko Woqgw!'
# [G  48] score=( -24,  -35,  -46): 'Idlko Wnrkw!'
# [G  49] score=( -23,  -34,  -43): 'Idllo Wnrkw!'
# [G  50] score=( -23,  -33,  -46): 'Idllo Wnrkw!'
# [G  51] score=( -24,  -32,  -41): 'Ielko Wnqkw!'
# [G  52] score=( -22,  -31,  -43): 'Iello Wnrkw!'
# [G  53] score=( -21,  -30,  -39): 'Idlko Wnqlt!'
# [G  54] score=( -21,  -29,  -38): 'Idlko Wnqlt!'
# [G  55] score=( -21,  -27,  -37): 'Iello Workw!'
# [G  56] score=( -19,  -26,  -37): 'Idlko Woqkr!'
# [G  57] score=( -19,  -25,  -32): 'Idlko Woqkr!'
# [G  58] score=( -18,  -24,  -33): 'Ielko Wnqlr!'
# [G  59] score=( -17,  -23,  -31): 'Iello Wnqlr!'
# [G  60] score=( -16,  -22,  -30): 'Iello Worls!'
# [G  61] score=( -16,  -21,  -30): 'Iello Worls!'
# [G  62] score=( -15,  -20,  -30): 'Iello Worlr!'
# [G  63] score=( -13,  -19,  -26): 'Iello Woslo!'
# [G  64] score=( -11,  -18,  -26): 'Gello Workm!'
# [G  65] score=( -11,  -17,  -26): 'Gello Workm!'
# [G  66] score=( -10,  -17,  -25): 'Gello Worlm!'
# [G  67] score=( -10,  -16,  -24): 'Gello Worlm!'
# [G  68] score=(  -7,  -15,  -24): 'Gello Worlj!'
# [G  69] score=(  -5,  -14,  -22): 'Gello Worlh!'
# [G  70] score=(  -5,  -13,  -22): 'Gello Worlh!'
# [G  71] score=(  -5,  -12,  -21): 'Gello Worlh!'
# [G  72] score=(  -3,  -11,  -20): 'Gello Woqlc!'
# [G  73] score=(  -3,  -10,  -18): 'Gello Woqlc!'
# [G  74] score=(  -3,   -9,  -21): 'Gello Worlf!'
# [G  75] score=(  -2,   -8,  -17): 'Gello Worlc!'
# [G  76] score=(  -2,   -7,  -16): 'Gello Worle!'
# [G  77] score=(  -2,   -6,  -15): 'Gello Worle!'
# [G  78] score=(  -2,   -5,  -15): 'Gelmo World!'
# [G  79] score=(  -1,   -5,  -13): 'Gello World!'
# [G  80] score=(  -1,   -4,  -12): 'Gello World!'
# [G  81] score=(  -1,   -4,  -11): 'Hello Worlc!'
# [G  82] score=(  -1,   -3,  -11): 'Hello Worlc!'
# [G  83] score=(  -1,   -3,   -9): 'Hello Worlc!'
# [G  84] score=(  -1,   -2,   -9): 'Hello Worle!'
# [G  85] score=(  -1,   -2,  -10): 'Hello Worle!'
# [G  86] score=(  -1,   -2,   -9): 'Hello Worle!'
# [G  87] score=(  -1,   -2,  -10): 'Hello Worle!'
# [G  88] score=(  -1,   -1,   -9): 'Iello World!'
# [G  89] score=(  -1,   -1,   -9): 'Hello Worle!'
# [G  90] score=(  -1,   -1,   -7): 'Iello World!'
# [G  91] score=(   0,   -1,   -9): 'Hello World!'
# [G  92] score=(   0,   -1,   -9): 'Hello World!'
# [G  93] score=(   0,   -1,   -8): 'Hello World!'
# [G  94] score=(   0,   -1,   -9): 'Hello World!'
# [G  95] score=(   0,   -1,   -8): 'Hello World!'
# [G  96] score=(   0,   -1,   -6): 'Hello World!'
# [G  97] score=(   0,   -1,   -7): 'Hello World!'
# [G  98] score=(   0,   -1,   -6): 'Hello World!'
# [G  99] score=(   0,   -1,   -6): 'Hello World!'
# [G 100] score=(   0,   -1,   -6): 'Hello World!'
# [G 101] score=(   0,   -1,   -8): 'Hello World!'
# [G 102] score=(   0,   -1,  -10): 'Hello World!'
# [G 103] score=(   0,   -1,   -8): 'Hello World!'
# [G 104] score=(   0,    0,   -6): 'Hello World!'
# [G 105] score=(   0,    0,   -7): 'Hello World!'
# [G 106] score=(   0,    0,   -6): 'Hello World!'
# [G 107] score=(   0,    0,   -6): 'Hello World!'
# [G 108] score=(   0,    0,   -9): 'Hello World!'
# [G 109] score=(   0,    0,   -8): 'Hello World!'
# [G 110] score=(   0,    0,   -5): 'Hello World!'
# [G 111] score=(   0,    0,   -5): 'Hello World!'
# [G 112] score=(   0,    0,   -7): 'Hello World!'
# [G 113] score=(   0,    0,   -5): 'Hello World!'
# [G 114] score=(   0,    0,   -7): 'Hello World!'
# [G 115] score=(   0,    0,   -5): 'Hello World!'
# [G 116] score=(   0,    0,   -7): 'Hello World!'
# [G 117] score=(   0,    0,   -9): 'Hello World!'
# [G 118] score=(   0,    0,   -8): 'Hello World!'
# [G 119] score=(   0,    0,   -9): 'Hello World!'
# [G 120] score=(   0,    0,   -8): 'Hello World!'
# [G 121] score=(   0,    0,   -5): 'Hello World!'
# [G 122] score=(   0,    0,   -8): 'Hello World!'
# [G 123] score=(   0,    0,   -9): 'Hello World!'
# [G 124] score=(   0,    0,   -5): 'Hello World!'
# [G 125] score=(   0,    0,   -9): 'Hello World!'
# [G 126] score=(   0,    0,   -6): 'Hello World!'
# [G 127] score=(   0,    0,   -7): 'Hello World!'
# [G 128] score=(   0,    0,   -7): 'Hello World!'
# [G 129] score=(   0,    0,   -6): 'Hello World!'
# [G 130] score=(   0,    0,   -8): 'Hello World!'
# [G 131] score=(   0,    0,   -7): 'Hello World!'
# [G 132] score=(   0,    0,   -9): 'Hello World!'
# [G 133] score=(   0,    0,   -9): 'Hello World!'
# [G 134] score=(   0,    0,   -8): 'Hello World!'
# [G 135] score=(   0,    0,   -7): 'Hello World!'
# [G 136] score=(   0,    0,   -9): 'Hello World!'
# [G 137] score=(   0,    0,   -6): 'Hello World!'
# [G 138] score=(   0,    0,   -6): 'Hello World!'
# [G 139] score=(   0,    0,   -6): 'Hello World!'
# [G 140] score=(   0,    0,   -6): 'Hello World!'
# [G 141] score=(   0,    0,   -6): 'Hello World!'
# [G 142] score=(   0,    0,   -8): 'Hello World!'
# [G 143] score=(   0,    0,   -8): 'Hello World!'
# [G 144] score=(   0,    0,   -7): 'Hello World!'
# [G 145] score=(   0,    0,   -6): 'Hello World!'
# [G 146] score=(   0,    0,   -5): 'Hello World!'
# [G 147] score=(   0,    0,   -5): 'Hello World!'
# [G 148] score=(   0,    0,   -6): 'Hello World!'
# [G 149] score=(   0,    0,   -6): 'Hello World!'
# [G 150] score=(   0,    0,   -8): 'Hello World!'
# [G 151] score=(   0,    0,   -5): 'Hello World!'
# [G 152] score=(   0,    0,   -7): 'Hello World!'
# [G 153] score=(   0,    0,   -5): 'Hello World!'
# [G 154] score=(   0,    0,   -6): 'Hello World!'
# [G 155] score=(   0,    0,   -8): 'Hello World!'
# [G 156] score=(   0,    0,   -6): 'Hello World!'
# [G 157] score=(   0,    0,   -5): 'Hello World!'
# [G 158] score=(   0,    0,   -9): 'Hello World!'
# [G 159] score=(   0,    0,   -9): 'Hello World!'
# [G 160] score=(   0,    0,   -5): 'Hello World!'
# [G 161] score=(   0,    0,   -5): 'Hello World!'
# [G 162] score=(   0,    0,   -6): 'Hello World!'
# [G 163] score=(   0,    0,   -6): 'Hello World!'
# [G 164] score=(   0,    0,   -8): 'Hello World!'
# [G 165] score=(   0,    0,   -8): 'Hello World!'
# [G 166] score=(   0,    0,   -8): 'Hello World!'
# [G 167] score=(   0,    0,   -8): 'Hello World!'
# [G 168] score=(   0,    0,   -6): 'Hello World!'
# [G 169] score=(   0,    0,   -7): 'Hello World!'
# [G 170] score=(   0,    0,   -5): 'Hello World!'
# [G 171] score=(   0,    0,   -7): 'Hello World!'
# [G 172] score=(   0,    0,   -9): 'Hello World!'
# [G 173] score=(   0,    0,   -8): 'Hello World!'
# [G 174] score=(   0,    0,   -9): 'Hello World!'
# [G 175] score=(   0,    0,   -9): 'Hello World!'
# [G 176] score=(   0,    0,  -10): 'Hello World!'
# [G 177] score=(   0,    0,   -6): 'Hello World!'
# [G 178] score=(   0,    0,   -6): 'Hello World!'
# [G 179] score=(   0,    0,   -8): 'Hello World!'
# [G 180] score=(   0,    0,   -5): 'Hello World!'
# [G 181] score=(   0,    0,   -8): 'Hello World!'
# [G 182] score=(   0,    0,   -8): 'Hello World!'
# [G 183] score=(   0,    0,   -6): 'Hello World!'
# [G 184] score=(   0,    0,   -6): 'Hello World!'
# [G 185] score=(   0,    0,   -6): 'Hello World!'
# [G 186] score=(   0,    0,   -8): 'Hello World!'
# [G 187] score=(   0,    0,   -9): 'Hello World!'
# [G 188] score=(   0,    0,   -5): 'Hello World!'
# [G 189] score=(   0,    0,   -6): 'Hello World!'
# [G 190] score=(   0,    0,   -5): 'Hello World!'
# [G 191] score=(   0,    0,   -6): 'Hello World!'
# [G 192] score=(   0,    0,   -8): 'Hello World!'
# [G 193] score=(   0,    0,   -8): 'Hello World!'
# [G 194] score=(   0,    0,   -5): 'Hello World!'
# [G 195] score=(   0,    0,   -8): 'Hello World!'
# [G 196] score=(   0,    0,   -6): 'Hello World!'
# [G 197] score=(   0,    0,   -6): 'Hello World!'
# [G 198] score=(   0,    0,   -5): 'Hello World!'
# [G 199] score=(   0,    0,   -5): 'Hello World!'
# [G 200] score=(   0,    0,   -9): 'Hello World!'

# %% [markdown]
# Fijaos como es capaz de llegar a la cadena "Hello World!" tras unas pocas generaciones!
#
# Esto también puede aplicarse a una red neuronal. Para ello, se puede hacer uso de una implementación disponible en Github: https://github.com/jliphard/DeepEvolve

# %% [markdown]
# Y os recomiendo que le echéis un ojo a estos dos enlaces en los que evolucionan una red neuronal con un GA. Aquí no nos da tiempo, pero son muy interesantes:
#
# ### Ejemplo GA para evolucionar NN:
#
# * https://blog.coast.ai/lets-evolve-a-neural-network-with-a-genetic-algorithm-code-included-8809bece164
# * https://github.com/harvitronix/neural-network-genetic-algorithm
